# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/NTU-research/Comformer
# Out:
# /content/drive/MyDrive/NTU-research/Comformer

# %%
# %pwd
# Out:
# '/content/drive/MyDrive/NTU-research/Comformer'

# %%
# !python train.py
# Out:
# 1. Prepare dataset...
# 2. Inital model...
# Using model: conformer
# Using GPU
# 3. Start training...
# The batch size is: 128
# Epoch 1: Train Loss = 0.6802, Train Acc = 0.5537, Val Loss = 0.6670, Val Acc = 0.5871
# Now the best model epoch is 1, and best val_acc is 0.5871
# Validation loss decreased (inf --> 0.667028).
# Epoch 2: Train Loss = 0.6104, Train Acc = 0.6615, Val Loss = 0.5030, Val Acc = 0.7613
# Now the best model epoch is 2, and best val_acc is 0.7613
# Validation loss decreased (0.667028 --> 0.502959).
# Epoch 3: Train Loss = 0.3838, Train Acc = 0.8309, Val Loss = 0.2230, Val Acc = 0.9167
# Now the best model epoch is 3, and best val_acc is 0.9167
# Validation loss decreased (0.502959 --> 0.222959).
# Epoch 4: Train Loss = 0.1399, Train Acc = 0.9496, Val Loss = 0.0796, Val Acc = 0.9752
# Now the best model epoch is 4, and best val_acc is 0.9752
# Validation loss decreased (0.222959 --> 0.079584).
# Epoch 5: Train Loss = 0.0562, Train Acc = 0.9833, Val Loss = 0.0465, Val Acc = 0.9854
# Now the best model epoch is 5, and best val_acc is 0.9854
# Validation loss decreased (0.079584 --> 0.046549).
# Epoch 6: Train Loss = 0.0353, Train Acc = 0.9899, Val Loss = 0.0317, Val Acc = 0.9903
# Now the best model epoch is 6, and best val_acc is 0.9903
# Validation loss decreased (0.046549 --> 0.031674).
# Epoch 7: Train Loss = 0.0272, Train Acc = 0.9919, Val Loss = 0.0294, Val Acc = 0.9906
# Now the best model epoch is 7, and best val_acc is 0.9906
# Validation loss decreased (0.031674 --> 0.029404).
# Epoch 8: Train Loss = 0.0180, Train Acc = 0.9953, Val Loss = 0.0218, Val Acc = 0.9930
# Now the best model epoch is 8, and best val_acc is 0.9930
# Validation loss decreased (0.029404 --> 0.021772).
# Epoch 9: Train Loss = 0.0155, Train Acc = 0.9960, Val Loss = 0.0179, Val Acc = 0.9942
# Now the best model epoch is 9, and best val_acc is 0.9942
# Validation loss decreased (0.021772 --> 0.017931).
# Epoch 10: Train Loss = 0.0126, Train Acc = 0.9968, Val Loss = 0.0311, Val Acc = 0.9892
# EarlyStopping counter: 1 out of 12
# Epoch 11: Train Loss = 0.0089, Train Acc = 0.9979, Val Loss = 0.0187, Val Acc = 0.9937
# EarlyStopping counter: 2 out of 12
# Epoch 12: Train Loss = 0.0074, Train Acc = 0.9983, Val Loss = 0.0124, Val Acc = 0.9959
# Now the best model epoch is 12, and best val_acc is 0.9959
# Validation loss decreased (0.017931 --> 0.012395).
# Epoch 13: Train Loss = 0.0055, Train Acc = 0.9989, Val Loss = 0.0105, Val Acc = 0.9965
# Now the best model epoch is 13, and best val_acc is 0.9965
# Validation loss decreased (0.012395 --> 0.010487).
# Epoch 14: Train Loss = 0.0045, Train Acc = 0.9991, Val Loss = 0.0140, Val Acc = 0.9952
# EarlyStopping counter: 1 out of 12
# Epoch 15: Train Loss = 0.0038, Train Acc = 0.9993, Val Loss = 0.0113, Val Acc = 0.9962
# EarlyStopping counter: 2 out of 12
# Epoch 16: Train Loss = 0.0027, Train Acc = 0.9997, Val Loss = 0.0076, Val Acc = 0.9974
# Now the best model epoch is 16, and best val_acc is 0.9974
# Validation loss decreased (0.010487 --> 0.007596).
# Epoch 17: Train Loss = 0.0018, Train Acc = 0.9999, Val Loss = 0.0070, Val Acc = 0.9976
# Now the best model epoch is 17, and best val_acc is 0.9976
# Validation loss decreased (0.007596 --> 0.006976).
# Epoch 18: Train Loss = 0.0019, Train Acc = 0.9997, Val Loss = 0.0112, Val Acc = 0.9962
# EarlyStopping counter: 1 out of 12
# Epoch 19: Train Loss = 0.0038, Train Acc = 0.9989, Val Loss = 0.0081, Val Acc = 0.9973
# EarlyStopping counter: 2 out of 12
# Epoch 20: Train Loss = 0.0010, Train Acc = 0.9999, Val Loss = 0.0052, Val Acc = 0.9981
# Now the best model epoch is 20, and best val_acc is 0.9981
# Validation loss decreased (0.006976 --> 0.005194).
# Epoch 21: Train Loss = 0.0005, Train Acc = 1.0000, Val Loss = 0.0065, Val Acc = 0.9979
# EarlyStopping counter: 1 out of 12
# Epoch 22: Train Loss = 0.0004, Train Acc = 1.0000, Val Loss = 0.0052, Val Acc = 0.9981
# Now the best model epoch is 22, and best val_acc is 0.9981
# Validation loss decreased (0.005194 --> 0.005193).
# Epoch 23: Train Loss = 0.0003, Train Acc = 1.0000, Val Loss = 0.0055, Val Acc = 0.9979
# EarlyStopping counter: 1 out of 12
# Epoch 24: Train Loss = 0.0003, Train Acc = 1.0000, Val Loss = 0.0049, Val Acc = 0.9982
# Now the best model epoch is 24, and best val_acc is 0.9982
# Validation loss decreased (0.005193 --> 0.004859).
# Epoch 25: Train Loss = 0.0003, Train Acc = 1.0000, Val Loss = 0.0054, Val Acc = 0.9981
# EarlyStopping counter: 1 out of 12
# Epoch 26: Train Loss = 0.0043, Train Acc = 0.9984, Val Loss = 0.0052, Val Acc = 0.9983
# Now the best model epoch is 26, and best val_acc is 0.9983
# EarlyStopping counter: 2 out of 12
# Epoch 27: Train Loss = 0.0003, Train Acc = 1.0000, Val Loss = 0.0046, Val Acc = 0.9985
# Now the best model epoch is 27, and best val_acc is 0.9985
# Validation loss decreased (0.004859 --> 0.004646).
# Epoch 28: Train Loss = 0.0002, Train Acc = 1.0000, Val Loss = 0.0045, Val Acc = 0.9986
# Now the best model epoch is 28, and best val_acc is 0.9986
# Validation loss decreased (0.004646 --> 0.004513).
# Epoch 29: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0045, Val Acc = 0.9985
# EarlyStopping counter: 1 out of 12
# Epoch 30: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0042, Val Acc = 0.9986
# Now the best model epoch is 30, and best val_acc is 0.9986
# Validation loss decreased (0.004513 --> 0.004187).
# Epoch 31: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0043, Val Acc = 0.9985
# EarlyStopping counter: 1 out of 12
# Epoch 32: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0042, Val Acc = 0.9986
# EarlyStopping counter: 2 out of 12
# Epoch 33: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0040, Val Acc = 0.9987
# Now the best model epoch is 33, and best val_acc is 0.9987
# Validation loss decreased (0.004187 --> 0.003978).
# Epoch 34: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0040, Val Acc = 0.9986
# EarlyStopping counter: 1 out of 12
# Epoch 35: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0039, Val Acc = 0.9987
# Now the best model epoch is 35, and best val_acc is 0.9987
# Validation loss decreased (0.003978 --> 0.003950).
# Epoch 36: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0040, Val Acc = 0.9987
# Now the best model epoch is 36, and best val_acc is 0.9987
# EarlyStopping counter: 1 out of 12
# Epoch 37: Train Loss = 0.0000, Train Acc = 1.0000, Val Loss = 0.0040, Val Acc = 0.9987
# EarlyStopping counter: 2 out of 12
# Epoch 38: Train Loss = 0.0000, Train Acc = 1.0000, Val Loss = 0.0036, Val Acc = 0.9987
# Validation loss decreased (0.003950 --> 0.003646).
# Epoch 39: Train Loss = 0.0000, Train Acc = 1.0000, Val Loss = 0.0035, Val Acc = 0.9988
# Now the best model epoch is 39, and best val_acc is 0.9988
# Validation loss decreased (0.003646 --> 0.003502).
# Epoch 40: Train Loss = 0.0000, Train Acc = 1.0000, Val Loss = 0.0123, Val Acc = 0.9979
# EarlyStopping counter: 1 out of 12
# Epoch 41: Train Loss = 0.0068, Train Acc = 0.9980, Val Loss = 0.0046, Val Acc = 0.9985
# EarlyStopping counter: 2 out of 12
# Epoch 42: Train Loss = 0.0002, Train Acc = 1.0000, Val Loss = 0.0047, Val Acc = 0.9984
# EarlyStopping counter: 3 out of 12
# Epoch 43: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0045, Val Acc = 0.9985
# EarlyStopping counter: 4 out of 12
# Epoch 44: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0044, Val Acc = 0.9986
# EarlyStopping counter: 5 out of 12
# Epoch 00045: reducing learning rate of group 0 to 1.0000e-06.
# Epoch 45: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0043, Val Acc = 0.9985
# EarlyStopping counter: 6 out of 12
# Epoch 46: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0043, Val Acc = 0.9986
# EarlyStopping counter: 7 out of 12
# Epoch 47: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0043, Val Acc = 0.9986
# EarlyStopping counter: 8 out of 12
# Epoch 48: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0043, Val Acc = 0.9986
# EarlyStopping counter: 9 out of 12
# Epoch 49: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0042, Val Acc = 0.9986
# EarlyStopping counter: 10 out of 12
# Epoch 50: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0042, Val Acc = 0.9986
# EarlyStopping counter: 11 out of 12
# Epoch 00051: reducing learning rate of group 0 to 1.0000e-07.
# Epoch 51: Train Loss = 0.0001, Train Acc = 1.0000, Val Loss = 0.0042, Val Acc = 0.9986
# EarlyStopping counter: 12 out of 12
# The Early stopping epoch is this： 50
# Figure(1000x800)
